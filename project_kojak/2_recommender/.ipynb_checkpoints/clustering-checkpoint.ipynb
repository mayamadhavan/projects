# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

import clustering_algorithms
from clustering_algorithms import clustering_pipeline
from clustering_algorithms import many_kmeans
from clustering_algorithms import many_db
from clustering_algorithms import many_meanshift
from clustering_algorithms import many_spectral
from clustering_algorithms import cosine_similarity
from clustering_algorithms import best_cluster

plt.style.use("seaborn")
# %matplotlib inline

# %% [markdown]
# # Read in Data

# %%
df=pd.read_csv('final_df.csv')
df=df.drop('Unnamed: 0', 1)
df.head()
# Out:
#                                   name  location.lat  location.lon  \
# 0             Alabama A & M University     34.783368    -86.568502
# 1  University of Alabama at Birmingham     33.502230    -86.809170
# 2  University of Alabama in Huntsville     34.722818    -86.638420
# 3             Alabama State University     32.364317    -86.295677
# 4            The University of Alabama     33.214400    -87.545766
#
#    minority_serving.historically_black  act_scores.midpoint.cumulative  \
# 0                                  1.0                            18.0
# 1                                  0.0                            25.0
# 2                                  0.0                            27.0
# 3                                  1.0                            18.0
# 4                                  0.0                            27.0
#
#    sat_scores.average.overall  demographics.race_ethnicity.white  \
# 0                       850.0                             0.0340
# 1                      1147.0                             0.5863
# 2                      1221.0                             0.7024
# 3                       844.0                             0.0165
# 4                      1181.0                             0.7807
#
#    net_price_less_30000  net_price_30001_48000  net_price_48001_75000  \
# 0               13075.0                12458.0                15857.0
# 1               13614.0                14746.0                17601.0
# 2               15252.0                17228.0                19178.0
# 3                7519.0                 2611.0                 9831.0
# 4               17263.0                19279.0                21309.0
#
#                       ...                      open_admissions_policy  \
# 0                     ...                                         2.0
# 1                     ...                                         2.0
# 2                     ...                                         2.0
# 3                     ...                                         2.0
# 4                     ...                                         2.0
#
#    accreditor_code  outcome_cohort.full_time.first_time.6yr  \
# 0           SACSCC                                   1044.0
# 1           SACSCC                                   1246.0
# 2           SACSCC                                    765.0
# 3           SACSCC                                   1330.0
# 4           SACSCC                                   5009.0
#
#    outcome_cohort.full_time.first_time.8yr  \
# 0                                   1044.0
# 1                                   1245.0
# 2                                    765.0
# 3                                   1330.0
# 4                                   5009.0
#
#    outcome_cohort.part_time.first_time.6yr  \
# 0                                      2.0
# 1                                     30.0
# 2                                     31.0
# 3                                     49.0
# 4                                     82.0
#
#    outcome_cohort.part_time.first_time.8yr  \
# 0                                      2.0
# 1                                     30.0
# 2                                     31.0
# 3                                     49.0
# 4                                     82.0
#
#    outcome_cohort.full_time.not_first_time.6yr  \
# 0                                        110.0
# 1                                        686.0
# 2                                        483.0
# 3                                        177.0
# 4                                       1131.0
#
#    outcome_cohort.full_time.not_first_time.8yr  \
# 0                                        110.0
# 1                                        686.0
# 2                                        483.0
# 3                                        177.0
# 4                                       1131.0
#
#    outcome_cohort.part_time.not_first_time.6yr  \
# 0                                         16.0
# 1                                        248.0
# 2                                        131.0
# 3                                         36.0
# 4                                        210.0
#
#   outcome_cohort.part_time.not_first_time.8yr
# 0                                        16.0
# 1                                       248.0
# 2                                       131.0
# 3                                        36.0
# 4                                       210.0
#
# [5 rows x 392 columns]

# %% [markdown]
# # Set Data Types

# %%
division=list(df.division)

# %%
df=df.drop(columns=['title_iv.approval_date', 'accreditor_code', 'city', 'state', 'Description', 'division', 'accreditor', 'school_url', 'price_calculator_url', 'rank_lac', 'Rank'])

# %%
names=df['name']
df=df.drop(columns=['name'])

# %%
for column in df.columns:
    try:
        df[f'{column}'].astype(float)
    except:
        new_col=[]
        for value in df[f'{column}']:
            try:
                new_col.append(float(value))
            except:
                new_col.append(0)
        df[f'{column}']=(new_col)

# %%
np.any(np.isnan(df))
# Out:
# False

# %%
df['division']=division

# %%
df=pd.get_dummies(df, columns=['division'])

# %%
df.dtypes
# Out:
# location.lat                                          float64
# location.lon                                          float64
# minority_serving.historically_black                   float64
# act_scores.midpoint.cumulative                        float64
# sat_scores.average.overall                            float64
# demographics.race_ethnicity.white                     float64
# net_price_less_30000                                  float64
# net_price_30001_48000                                 float64
# net_price_48001_75000                                 float64
# net_price_75001_110000                                float64
# net_price_above_110001                                float64
# demographics.women                                    float64
# locale                                                float64
# admission_rate.overall                                float64
# size                                                  float64
# early_pay                                             float64
# ownership                                               int64
# percent_stem                                          float64
# index                                                   int64
# id                                                      int64
# ope8_id                                                 int64
# ope6_id                                                 int64
# zip                                                   float64
# under_investigation                                     int64
# main_campus                                             int64
# branches                                                int64
# degrees_awarded.predominant                             int64
# degrees_awarded.highest                                 int64
# state_fips                                              int64
# region_id                                               int64
#                                                        ...
# students_with_any_loan                                float64
# students_with_pell_grant                              float64
# demographics.age_entry                                float64
# demographics.female_share                             float64
# demographics.married                                  float64
# demographics.dependent                                float64
# demographics.veteran                                  float64
# demographics.first_generation                         float64
# demographics.avg_family_income                        float64
# demographics.median_family_income                     float64
# demographics.avg_family_income_independents           float64
# median_debt_suppressed.overall                        float64
# median_debt_suppressed.completers.overall             float64
# median_debt_suppressed.completers.monthly_payments    float64
# institutional_characteristics.level                     int64
# demographics.men                                      float64
# undergrads_with_pell_grant_or_federal_student_loan    float64
# open_admissions_policy                                float64
# outcome_cohort.full_time.first_time.6yr               float64
# outcome_cohort.full_time.first_time.8yr               float64
# outcome_cohort.part_time.first_time.6yr               float64
# outcome_cohort.part_time.first_time.8yr               float64
# outcome_cohort.full_time.not_first_time.6yr           float64
# outcome_cohort.full_time.not_first_time.8yr           float64
# outcome_cohort.part_time.not_first_time.6yr           float64
# outcome_cohort.part_time.not_first_time.8yr           float64
# division_D1                                             uint8
# division_D2                                             uint8
# division_D3                                             uint8
# division_non_ncaa                                       uint8
# Length: 384, dtype: object

# %% [markdown]
# # EDA

# %%
f, ax = plt.subplots(figsize=(20,20))

sns.heatmap(df.corr(), cmap="seismic");

# %%
df.corr()[df.corr()>0.75]

# %% [markdown]
# # Scale

# %%
df_std = StandardScaler().fit_transform(df)

# %% [markdown]
# # Choose Number of Components For PCA
# Using PCA to Reduce Dimensionality
# + Decreases Interperetability, Going to Review Clusters After to Choose Best Cluster

# %%
cluster=clustering_algorithms.clustering_pipeline(100)

# %%
cluster.fit(df_std)

# %%
cluster.pca_plot()

# %% [markdown]
# # Choose Perplexity for TSNE

# %%
cluster.kmeans(10)

# %%
# cluster.tsne(2, 5)
# cluster.tsne(2, 25)
cluster.tsne(2, 30)
# cluster.tsne(2, 40)
# cluster.tsne(2, 50)

# %% [markdown]
# # KMeans

# %%
km_cluster=clustering_algorithms.clustering_pipeline(100)

# %%
km_cluster.fit(df_std)

# %%
many_kmeans(km_cluster, 15, df_std, names, 2, 30)

# %% [markdown]
# # DBSCAN

# %%
db_cluster=clustering_algorithms.clustering_pipeline(100)
db_cluster.fit(df_std)

many_db(db_cluster, eps=17, min_samples=3)

# %%
db_cluster.n_clusters

# %%
sum([1 for label in db_cluster.labels_ if label == -1]) / len(db_cluster.labels_)

# %%
db_cluster.tsne(2, 30);

# %% [markdown]
# # Mean Shift

# %%
ms_cluster=clustering_algorithms.clustering_pipeline(100)

# %%
ms_cluster.fit(df_std)

# %%
many_meanshift(ms_cluster, 0.3, 10, df_std, names)

# %%
ms_cluster.tsne(2, 30);

# %% [markdown]
# # Spectral
# See 'Spectral Notebook', created due to time constraints

# %%
df.to_pickle('spectral.pkl')

# %% [markdown]
# # Finding the Closest Schools to A Given One

# %%
def three_closest_to_x(cluster, x, column):
    x= list(column).index(x)
    overall_clusters=[]
    distances=[]
    for index, vector in enumerate(cluster.data):
        dist = cosine_similarity(cluster.data[x],vector)
        distances.append((dist, index))
    distances.sort()
    indices=[x[1] for x in distances[-4:]]
    print( f"\n + {distances[-4:]}")
    for i in indices:
        print("\n" + column[i])

# %% [markdown]
# # Final Cluster and Sample Output

# %% [markdown]
# Create and Fit Cluster

# %%
final_cluster=clustering_algorithms.clustering_pipeline(100)
final_cluster.fit(df_std)

# %% [markdown]
# Run Kmeans with 12 Clusters

# %%
final_cluster.kmeans(10)

# %% [markdown]
# View TSNE

# %%
final_cluster.tsne(2,30)

# %% [markdown]
# **Discern Meaning** Using points closest and farthest to centroids

# %%
best_cluster(final_cluster, df, names)
# Out:
#  + [(0.9166797742887746, 1380), (0.9191346455148266, 1176), (0.9310811292938664, 1377), (0.9331554672992065, 1373)]
#
# Closest to Center
# Inter American University of Puerto Rico-Fajardo
# Inter American University of Puerto Rico-Arecibo
# Inter American University of Puerto Rico-Guayama
# Colegio Universitario de San Juan
#
# Farthest from Center
# Simpson College
# Luther College
# Duquesne University
# Otterbein University
#
#  + [(0.8908184809095031, 692), (0.892518442043709, 913), (0.8944840283923444, 1304), (0.9141637765403152, 463)]
#
# Closest to Center
# Saint Anselm College
# John Carroll University
# Gonzaga University
# Loyola University Maryland
#
# Farthest from Center
# Louisiana State University-Alexandria
# The University of Texas Rio Grande Valley
# Northwestern State University of Louisiana
# Missouri Southern State University
#
#  + [(0.7013990657310692, 1263), (0.7104094760207692, 570), (0.7741931231420208, 865), (0.7886822439572406, 384)]
#
# Closest to Center
# Bluefield College
# Spring Arbor University
# University of Mount Olive
# MidAmerica Nazarene University
#
# Farthest from Center
# SUNY College at Geneseo
# SUNY at Binghamton
# College of William and Mary
# University of Notre Dame
#
#  + [(0.6837327528925273, 661), (0.7197713594467335, 135), (0.7296209877633903, 51), (0.74131910651948, 806)]
#
# Closest to Center
# Montana State University-Northern
# Colorado Mesa University
# University of Arkansas-Fort Smith
# SUNY College of Technology at Delhi
#
# Farthest from Center
# Stetson University
# Loyola University New Orleans
# Lynchburg College
# Wittenberg University
#
#  + [(0.7291936409379918, 416), (0.7311493421969825, 677), (0.7542972150773023, 674), (0.81745995705772, 861)]
#
# Closest to Center
# Union College
# York College
# Union College
# Mars Hill University
#
# Farthest from Center
# Rutgers University-New Brunswick
# Northeastern University
# George Mason University
# University of Connecticut
#
#  + [(0.8374503426714797, 173), (0.8621281096057967, 869), (0.8651581358681091, 186), (0.8790954101921863, 1215)]
#
# Closest to Center
# University of Central Florida
# University of North Carolina at Charlotte
# University of Florida
# Texas State University
#
# Farthest from Center
# Clarke University
# Southern Vermont College
# Hartwick College
# Silver Lake College of the Holy Family
#
#  + [(0.9045372250505375, 444), (0.9062962890568715, 130), (0.9357087840138448, 1008), (0.9373924403796886, 585)]
#
# Closest to Center
# Colby College
# Colorado College
# Franklin and Marshall College
# Macalester College
#
# Farthest from Center
# Northwestern State University of Louisiana
# Austin Peay State University
# University of South Carolina-Upstate
# University of Mount Olive
#
#  + [(0.2975456743719836, 1071), (0.3049836890252464, 1096), (0.3573332063046111, 286), (1.0, 485)]
#
# Closest to Center
# Saint Vincent College
# Providence College
# Northwestern University
# Boston University
#
# Farthest from Center
# West Virginia State University
# University of Wisconsin-Parkside
# Blue Mountain College
# Concord University
#
#  + [(0.2623651765985668, 1078), (0.2835686304897097, 455), (0.30851002217906864, 1294), (1.0, 556)]
#
# Closest to Center
# Temple University
# University of Baltimore
# Virginia Commonwealth University
# Madonna University
#
# Farthest from Center
# College of Charleston
# Salisbury University
# Eastern Connecticut State University
# SUNY College at Geneseo
#
#  + [(0.9484253711877115, 1057), (0.9484396548739336, 1052), (0.9487224974175982, 1048), (0.9539495799181665, 1047)]
#
# Closest to Center
# Pennsylvania State University-Penn State Schuylkill
# Pennsylvania State University-Penn State Hazleton
# Pennsylvania State University-Penn State Harrisburg
# Pennsylvania State University-Penn State Berks
#
# Farthest from Center
# Catawba College
# Union College
# Hardin-Simmons University
# Union College

# %% [markdown]
# Some Sample Schools

# %%
three_closest_to_x(final_cluster, x='Wellesley College', column=names)
# Out:
#  + [(0.8250140923595985, 478), (0.8441767938479275, 116), (0.9000384685512034, 729), (1.0, 527)]
#
# Amherst College
#
# Scripps College
#
# Barnard College
#
# Wellesley College

# %%
three_closest_to_x(final_cluster, x='Claremont McKenna College', column=names)
# Out:
#  + [(0.8294704583155325, 733), (0.8298677810161676, 108), (0.8358670990988437, 442), (1.0, 84)]
#
# Colgate University
#
# Pomona College
#
# Bates College
#
# Claremont McKenna College

# %%
three_closest_to_x(final_cluster, x='Harvey Mudd College', column=names)
# Out:
#  + [(0.7694914671854212, 1023), (0.7727584361086226, 579), (0.7907984195032712, 55), (1.0, 89)]
#
# Lafayette College
#
# Carleton College
#
# California Institute of Technology
#
# Harvey Mudd College

# %%
three_closest_to_x(final_cluster, x='Princeton University', column=names)
# Out:
#  + [(0.8507590005348827, 848), (0.8624312612868262, 1203), (0.8785980426390136, 159), (1.0, 708)]
#
# Duke University
#
# Rice University
#
# Yale University
#
# Princeton University
