# %% [markdown]
# Features of Interest:
# 1. Rank
# 2. Athletics
# 3. Salary After Graduation
# 4. % in Dorms
# 5. Student Teacher Ratio

# %%
import pandas as pd

# %% [markdown]
# # NCAA Divisions

# %% [markdown]
# ## D1

# %%
d1=pd.read_html('https://en.wikipedia.org/wiki/List_of_NCAA_Division_I_institutions')[0]
d1.tail()
# Out:
#                                0                     1           2  \
# 347      Wright State University               Raiders    Fairborn
# 348        University of Wyoming  Cowboys and Cowgirls     Laramie
# 349            Xavier University            Musketeers  Cincinnati
# 350              Yale University              Bulldogs   New Haven
# 351  Youngstown State University              Penguins  Youngstown
#
#                3                      4                         5
# 347         Ohio                  State            Horizon League
# 348      Wyoming                  State  Mountain West Conference
# 349         Ohio       Private/Catholic       Big East Conference
# 350  Connecticut  Private/Non-Sectarian                Ivy League
# 351         Ohio                  State         Horizon League[h]

# %%
d1.columns = d1.iloc[0]
d1=d1.reindex(d1.index.drop(0))
d1.head()
# Out:
# 0                                          School                        Team  \
# 1                    Abilene Christian University                    Wildcats
# 2                             University of Akron                        Zips
# 3                           University of Alabama                Crimson Tide
# 4  Alabama Agricultural and Mechanical University  Bulldogs and Lady Bulldogs
# 5             University of Alabama at Birmingham                     Blazers
#
# 0        City    State                        Type  \
# 1     Abilene    Texas  Private/Churches of Christ
# 2       Akron     Ohio                       State
# 3  Tuscaloosa  Alabama                       State
# 4  Huntsville  Alabama                       State
# 5  Birmingham  Alabama                       State
#
# 0                Primary Conference
# 1              Southland Conference
# 2           Mid-American Conference
# 3           Southeastern Conference
# 4  Southwestern Athletic Conference
# ...

# %% [markdown]
# ## D2

# %%
d2=pd.read_html('https://en.wikipedia.org/wiki/List_of_NCAA_Division_II_institutions')[0]
d2.tail()
# Out:
#                                     0               1              2  \
# 298                Wingate University        Bulldogs        Wingate
# 299           Winona State University        Warriors         Winona
# 300    Winston–Salem State University            Rams  Winston–Salem
# 301  University of Wisconsin–Parkside         Rangers        Kenosha
# 302              Young Harris College  Mountain Lions   Young Harris
#
#                   3                                                4
# 298  North Carolina                        South Atlantic Conference
# 299       Minnesota          Northern Sun Intercollegiate Conference
# 300  North Carolina     Central Intercollegiate Athletic Association
# 301       Wisconsin  Great Lakes Intercollegiate Athletic Conference
# 302         Georgia                            Peach Belt Conference

# %%
d2.columns = d2.iloc[0]
d2=d2.reindex(d2.index.drop(0))
d2.head()
# Out:
# 0                               School       Nickname           City  \
# 1            Academy of Art University  Urban Knights  San Francisco
# 2               Adams State University      Grizzlies        Alamosa
# 3                   Adelphi University       Panthers    Garden City
# 4  University of Alabama in Huntsville       Chargers     Huntsville
# 5       University of Alaska Fairbanks        Nanooks      Fairbanks
#
# 0 State/Province                           Conference
# 1     California              Pacific West Conference
# 2       Colorado   Rocky Mountain Athletic Conference
# 3       New York              Northeast-10 Conference
# 4        Alabama                Gulf South Conference
# 5         Alaska  Great Northwest Athletic Conference

# %% [markdown]
# ## D3

# %%
d3=pd.read_html('https://en.wikipedia.org/wiki/List_of_NCAA_Division_III_institutions')[0]
d3.tail()
# Out:
#                                              0          1          2  \
# 448            Worcester Polytechnic Institute  Engineers  Worcester
# 449                 Worcester State University    Lancers  Worcester
# 450                         Yeshiva University  Maccabees   New York
# 451  York College, City University of New York  Cardinals     Queens
# 452               York College of Pennsylvania   Spartans       York
#
#                  3                                                  4
# 448  Massachusetts  New England Women's and Men's Athletic Conference
# 449  Massachusetts  Massachusetts State Collegiate Athletic Confer...
# 450       New York                                 Skyline Conference
# 451       New York    City University of New York Athletic Conference
# 452   Pennsylvania                        Capital Athletic Conference

# %%
d3.columns = d3.iloc[0]
d3=d3.reindex(d3.index.drop(0))
d3.head()
# Out:
# 0                   School  Nickname       City         State  \
# 1           Adrian College  Bulldogs     Adrian      Michigan
# 2      Agnes Scott College  Scotties    Decatur       Georgia
# 3  Albertus Magnus College   Falcons  New Haven   Connecticut
# 4           Albion College   Britons     Albion      Michigan
# 5         Albright College     Lions    Reading  Pennsylvania
#
# 0                                     Conference
# 1  Michigan Intercollegiate Athletic Association
# 2                  USA South Athletic Conference
# 3            Great Northeast Athletic Conference
# 4  Michigan Intercollegiate Athletic Association
# 5                    MAC Commonwealth Conference

# %% [markdown]
# # Rank- Non LAC

# %%
rank=pd.read_csv('Data/National Universities Rankings.csv', encoding='latin-1')
rank.head()
# Out:
#                     Name       Location  Rank  \
# 0   Princeton University  Princeton, NJ     1
# 1     Harvard University  Cambridge, MA     2
# 2  University of Chicago    Chicago, IL     3
# 3        Yale University  New Haven, CT     3
# 4    Columbia University   New York, NY     5
#
#                                          Description Tuition and fees  \
# 0  Princeton, the fourth-oldest college in the Un...         $45,320
# 1  Harvard is located in Cambridge, Massachusetts...         $47,074
# 2  The University of Chicago, situated in Chicago...         $52,491
# 3  Yale University, located in New Haven, Connect...         $49,480
# 4  Columbia University, located in Manhattan's Mo...         $55,056
#
#   In-state Undergrad Enrollment
# 0      NaN                5,402
# 1      NaN                6,699
# 2      NaN                5,844
# 3      NaN                5,532
# 4      NaN                6,102
